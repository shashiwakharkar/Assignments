# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
comp_df = pd.read_csv('Computer_Data.csv')
comp_df
# Out:
#       Unnamed: 0  price  speed    hd  ram  screen   cd multi premium  ads  \
# 0              1   1499     25    80    4      14   no    no     yes   94
# 1              2   1795     33    85    2      14   no    no     yes   94
# 2              3   1595     25   170    4      15   no    no     yes   94
# 3              4   1849     25   170    8      14   no    no      no   94
# 4              5   3295     33   340   16      14   no    no     yes   94
# ...          ...    ...    ...   ...  ...     ...  ...   ...     ...  ...
# 6254        6255   1690    100   528    8      15   no    no     yes   39
# 6255        6256   2223     66   850   16      15  yes   yes     yes   39
# 6256        6257   2654    100  1200   24      15  yes    no     yes   39
# 6257        6258   2195    100   850   16      15  yes    no     yes   39
# 6258        6259   2490    100   850   16      17  yes    no     yes   39
#
#       trend
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
#comp_df.drop(['cd', 'multi', 'premium'], axis = 1)
comp_df.drop(comp_df.columns[[0, 6, 7, 8]], axis = 1, inplace = True)
comp_df
# Out:
#       price  speed    hd  ram  screen  ads  trend
# 0      1499     25    80    4      14   94      1
# 1      1795     33    85    2      14   94      1
# 2      1595     25   170    4      15   94      1
# 3      1849     25   170    8      14   94      1
# 4      3295     33   340   16      14   94      1
# ...     ...    ...   ...  ...     ...  ...    ...
# 6254   1690    100   528    8      15   39     35
# 6255   2223     66   850   16      15   39     35
# 6256   2654    100  1200   24      15   39     35
# 6257   2195    100   850   16      15   39     35
# 6258   2490    100   850   16      17   39     35
#
# [6259 rows x 7 columns]

# %%
comp_df.boxplot(grid = False)

# %%
for column in comp_df:
    plt.figure()
    comp_df.boxplot([column])

# %%
fig, ax = plt.subplots(figsize = (15, 12),)
comp_df.hist(ax = ax)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D20FA94E88>,
# ...
#       dtype=object)

# %%
sns.distplot(a = comp_df["price"], kde = True,
kde_kws={"color" : "g", "alpha" : 0.3, "linewidth" : 3, "shade" : False})

# %%
sns.kdeplot(comp_df["price"], shade = True)
